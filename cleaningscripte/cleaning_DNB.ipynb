# %% [markdown]
# # cleaning des data diplome Natianal du brevet
# analyse sur le ficheir "data/Second_deg_Colleges/fr-en-ips_colleges2016_2021.csv"
# - source 2016-2021=> https://www.data.gouv.fr/fr/datasets/r/b63bd365-c589-48e4-b7d8-9e4f5db133c5
# - source 2022 + => https://www.data.gouv.fr/fr/datasets/r/28e511a7-af0d-48c7-a8bb-2f38ec003f49

# %%
import pandas as pd
import seaborn as sns
import os
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv("./.env"))
path3 = os.environ.get("GEOCOORD") #Variable globale pour le chemin vers fichier coordonnées géographiques.

# %%
dfDNB = pd.read_csv(os.path.join(path2,"fr-en-dnb-par-etablissement.csv"), sep=";")

# %%
# résultats du brevet
dfDNB.head()
# Out:
#    Session Numero d'etablissement Type d'etablissement      Patronyme  \
# 0     2017               0541333F              COLLEGE   JOLIOT CURIE
# 1     2017               0541370W  LYCEE PROFESSIONNEL  CLAUDE DAUNOT
# 2     2017               0541579Y              COLLEGE    EMILE GALLE
# 3     2017               0550013R              COLLEGE   VAL D'ORNOIS
# 4     2017               0550960V  LYCEE PROFESSIONNEL         STENAY
#
#   Secteur d'enseignement Commune         Libellé commune Code département  \
# 0                 PUBLIC   54536            TUCQUEGNIEUX              054
# 1                  PRIVE   54395                   NANCY              054
# 2                 PUBLIC   54314                    LEXY              054
# 3                 PUBLIC   55215  GONDRECOURT-LE-CHATEAU              055
# 4                  PRIVE   55502                  STENAY              055
#
#   Libellé département  Code académie  ... Code région  Libellé région  \
# ...

# %%
dfDNB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139580 entries, 0 to 139579
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Session                    139580 non-null  int64
#  1   Numero d'etablissement     139580 non-null  object
#  2   Type d'etablissement       139580 non-null  object
#  3   Patronyme                  139479 non-null  object
#  4   Secteur d'enseignement     139580 non-null  object
#  5   Commune                    139580 non-null  object
#  6   Libellé commune            139580 non-null  object
#  7   Code département           139580 non-null  object
#  8   Libellé département        139580 non-null  object
#  9   Code académie              139580 non-null  int64
#  10  Libellé académie           139580 non-null  object
#  11  Code région                139580 non-null  int64
#  12  Libellé région             139580 non-null  object
# ...

# %%
dfDNB["Numero d'etablissement"].nunique()
# Il y a plus d'établissements qui font passer le brevet que de collèges en France.
#  En effet, a priori, certains lycées font passer le brevet, notamment les lycées professionnels, CFA,
# Out:
# 9608

# %%
dfDNB.groupby('Type d\'etablissement').nunique()
# Out:
#                       Session  Numero d'etablissement  Patronyme  \
# Type d'etablissement
# AUTRE                      16                      31          1
# CFA                        16                      30         31
# COLLEGE                    16                    7231       4854
# EREA                       16                      63         69
# LYCEE                      16                     656        708
# LYCEE PROFESSIONNEL        16                    1701       2233
#
#                       Secteur d'enseignement  Commune  Libellé commune  \
# Type d'etablissement
# AUTRE                                      1        1                1
# CFA                                        2       28               28
# COLLEGE                                    2     3902             3868
# EREA                                       2       63               63
# LYCEE                                      2      537              537
# ...

# %%
#recalculons le taux de réussite.
dfDNB["Taux de réussite"] = round(dfDNB.Admis / dfDNB.Inscrits, 3)

# %%
# Ne gardons que les résultats.avec les années d'IPS, à savoir 2016, 
# et donc session 2017 et plus.
dfDNB = dfDNB[dfDNB.Session > 2016]
