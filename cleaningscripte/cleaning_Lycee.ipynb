# %% [markdown]
# # EDA Lycées
#
# - source 2016-2021=> https://www.data.gouv.fr/fr/datasets/r/27d469ff-9908-4b7e-a2e0-9439bb38a395
# - source 2022 + => https://www.data.gouv.fr/fr/datasets/r/df2cbcb3-da0a-4265-a24e-c36f2c787db2

# %%
# Importing useful libraries
import pandas as pd
import seaborn as sns
# view all possible rows and columns
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
import os
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv("./.env"))
path2 = os.environ.get("IPSLYC") #Variable globale pour le fichier des IPS de collège.
# read datasets
df_2016 = pd.read_csv(os.path.join(path2, "fr-en-ips_lycees_2016_2021.csv"), sep=";")
df_2022 = pd.read_csv(os.path.join(path2, "fr-en-ips-lycees-ap2022.csv"), sep=";")
df_bac = pd.read_csv(os.path.join(path2, "fr-en-indicateurs-de-resultat-des-lycees-denseignement-general-et-technologique.csv"), sep=";")
#df_2022 = pd.read_csv("fr-en-ips-lycees-ap2022.csv", sep=";")
#df_bac = pd.read_csv("fr-en-indicateurs-de-resultat-des-lycees-denseignement-general-et-technologique.csv", sep=";")
# Out:
# C:\Users\naomi\AppData\Local\Temp\ipykernel_11584\2697592960.py:6: DtypeWarning: Columns (47,48,49,51,52,53,55,56,57,58,59,71,72,73,74,75,76,77,78,79,80,81,95,98,100,111,113,115,122,123,124,126,131,134,136) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_bac = pd.read_csv(os.path.join(path2, "fr-en-indicateurs-de-resultat-des-lycees-denseignement-general-et-technologique.csv"), sep=";")

# %%
df_2016.describe()
# Out:
#        code_du_departement  code_insee_de_la_commune   ips_voie_gt  \
# count         21687.000000              21687.000000  14792.000000
# mean             89.278738              55615.463227    113.690265
# std             179.189360              27538.803893     15.170934
# min               1.000000               1004.000000     51.900000
# 25%              33.000000              33063.000000    105.000000
# 50%              59.000000              59365.000000    113.100000
# 75%              77.000000              77258.000000    122.900000
# max             976.000000              97801.000000    159.100000
#
#        ips_voie_pro  ips_ensemble_gt_pro  ecart_type_de_l_ips_voie_gt  \
# count  12556.000000         21777.000000                  7411.000000
# mean      86.955384           103.181696                    33.534165
# std       10.914099            18.828389                     3.712477
# min       47.300000            49.500000                     0.000000
# ...

# %%
df_2022.describe()
# Out:
#        effectifs_voie_gt  effectifs_voie_pro  effectifs_ensemble_gt_pro  \
# count        2464.000000         2075.000000                3598.000000
# mean          642.446023          280.994699                 602.015286
# std           401.353961          170.056184                 412.356972
# min             5.000000            5.000000                   5.000000
# 25%           313.000000          155.000000                 275.000000
# 50%           603.500000          260.000000                 499.500000
# 75%           942.250000          372.000000                 883.000000
# max          2453.000000         1425.000000                2453.000000
#
#        ips_voie_gt  ips_voie_pro  ips_ensemble_gt_pro  \
# count  2464.000000   2075.000000          3598.000000
# mean    114.843831     91.137398           105.795053
# std      14.758875     11.560655            17.764091
# min      67.900000     62.300000            64.100000
# ...

# %%
df_bac.describe()
# Out:
#               Annee  Presents - L  Presents - ES  Presents - S  \
# count  27808.000000  16111.000000   17813.000000  18977.000000
# mean    2017.509889     29.835951      58.002695     85.790009
# std        3.447927     19.038794      32.610631     50.798670
# min     2012.000000      1.000000       1.000000      3.000000
# 25%     2015.000000     16.000000      32.000000     47.000000
# 50%     2018.000000     26.000000      54.000000     78.000000
# 75%     2021.000000     39.000000      79.000000    118.000000
# max     2023.000000    161.000000     236.000000    346.000000
#
#        Presents - STG  Presents - STI2D  Presents - STD2A  Presents - STMG  \
# count     2483.000000       6641.000000       1029.000000     12527.000000
# mean        55.977447         49.771571         34.214772        55.935100
# std         32.027403         31.765757         12.605567        31.398072
# min          1.000000          1.000000          1.000000         1.000000
# ...

# %%
df_2016.dtypes
# Out:
# rentree_scolaire                 object
# academie                         object
# code_du_departement             float64
# departement                      object
# uai                              object
# nom_de_l_etablissment            object
# code_insee_de_la_commune        float64
# nom_de_la_commune                object
# secteur                          object
# type_de_lycee                    object
# ips_voie_gt                     float64
# ips_voie_pro                    float64
# ips_ensemble_gt_pro             float64
# ecart_type_de_l_ips_voie_gt     float64
# ecart_type_de_l_ips_voie_pro    float64
# dtype: object

# %%
df_2022.dtypes
# Out:
# rentree_scolaire                 object
# academie                         object
# code_du_departement              object
# departement                      object
# uai                              object
# nom_de_l_etablissment            object
# code_insee_de_la_commune         object
# nom_de_la_commune                object
# secteur                          object
# type_de_lycee                    object
# effectifs_voie_gt               float64
# effectifs_voie_pro              float64
# effectifs_ensemble_gt_pro       float64
# ips_voie_gt                     float64
# ips_voie_pro                    float64
# ips_ensemble_gt_pro             float64
# ecart_type_de_l_ips_voie_gt     float64
# ecart_type_de_l_ips_voie_pro    float64
# dtype: object

# %%
df_bac.dtypes
# Out:
# Etablissement                                                       object
# Annee                                                                int64
# Ville                                                               object
# UAI                                                                 object
# Code commune                                                        object
# Academie                                                            object
# Departement                                                         object
# Secteur                                                             object
# Presents - L                                                       float64
# Presents - ES                                                      float64
# Presents - S                                                       float64
# Presents - STG                                                     float64
# ...

# %%
# check NAN values
df_2016.isna().sum()
# Out:
# rentree_scolaire                    0
# academie                            0
# code_du_departement                90
# departement                         0
# uai                                 0
# nom_de_l_etablissment               0
# code_insee_de_la_commune           90
# nom_de_la_commune                   0
# secteur                             0
# type_de_lycee                       0
# ips_voie_gt                      6985
# ips_voie_pro                     9221
# ips_ensemble_gt_pro                 0
# ecart_type_de_l_ips_voie_gt     14366
# ecart_type_de_l_ips_voie_pro    15503
# dtype: int64

# %%
# check NAN values
df_2022.isna().sum()
# Out:
# rentree_scolaire                   0
# academie                           0
# code_du_departement                0
# departement                        0
# uai                                0
# nom_de_l_etablissment              0
# code_insee_de_la_commune           0
# nom_de_la_commune                  0
# secteur                            0
# type_de_lycee                      0
# effectifs_voie_gt               1134
# effectifs_voie_pro              1523
# effectifs_ensemble_gt_pro          0
# ips_voie_gt                     1134
# ips_voie_pro                    1523
# ips_ensemble_gt_pro                0
# ecart_type_de_l_ips_voie_gt     1134
# ecart_type_de_l_ips_voie_pro    1523
# dtype: int64

# %% [markdown]
# Normalisation des data 2016-2022
# - Normalisé_x = (x - min(x)) / (max(x) - min(x))

# %%
df_2016['ips_ensemble_gt_pro']= df_2016['ips_ensemble_gt_pro'] / df_2016['ips_ensemble_gt_pro'].abs().max()
df_2022['ips_ensemble_gt_pro']= df_2022['ips_ensemble_gt_pro'] / df_2022['ips_ensemble_gt_pro'].abs().max()

# %%
fig2016 = sns.displot(df_2016, x='ips_ensemble_gt_pro', hue='type_de_lycee')
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig2022 = sns.displot(df_2022, x='ips_ensemble_gt_pro', hue='type_de_lycee')
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.heatmap(df_2016.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(df_2022.isnull())
# Out:
# <Axes: >

# %%
df_1622 = pd.concat([df_2016 ,df_2022], axis=0)

# %%
df_1622 = df_1622.reset_index()
sns.heatmap(df_1622.isna())
# Out:
# <Axes: >

# %%
df_1622.describe()
# Out:
#               index   ips_voie_gt  ips_voie_pro  ips_ensemble_gt_pro  \
# count  25375.000000  17256.000000  14631.000000         25375.000000
# mean    9599.171586    113.854984     87.548486             0.648607
# std     6642.635515     15.117750     11.103970             0.117059
# min        0.000000     51.900000     47.300000             0.311125
# 25%     3171.500000    105.000000     80.600000             0.556254
# 50%     9089.000000    113.300000     86.700000             0.646763
# 75%    15432.500000    123.100000     93.600000             0.729101
# max    21776.000000    163.000000    136.500000             1.000000
#
#        ecart_type_de_l_ips_voie_gt  ecart_type_de_l_ips_voie_pro  \
# count                  9875.000000                   8349.000000
# mean                     32.884891                     28.069853
# std                       4.077060                      3.839765
# min                       0.000000                      0.000000
# ...

# %%
# ajout des résultats du bac
df = df_1622.merge(df_bac, how='left', left_on="uai", right_on="UAI" )

# %%
df.head()
# Out:
#    index rentree_scolaire academie code_du_departement     departement  \
# 0      0        2018-2019  CRETEIL                77.0  SEINE-ET-MARNE
# 1      0        2018-2019  CRETEIL                77.0  SEINE-ET-MARNE
# 2      0        2018-2019  CRETEIL                77.0  SEINE-ET-MARNE
# 3      0        2018-2019  CRETEIL                77.0  SEINE-ET-MARNE
# 4      0        2018-2019  CRETEIL                77.0  SEINE-ET-MARNE
#
#         uai            nom_de_l_etablissment code_insee_de_la_commune  \
# 0  0770940D  LYCEE POLYVALENT ETIENNE BEZOUT                  77333.0
# 1  0770940D  LYCEE POLYVALENT ETIENNE BEZOUT                  77333.0
# 2  0770940D  LYCEE POLYVALENT ETIENNE BEZOUT                  77333.0
# 3  0770940D  LYCEE POLYVALENT ETIENNE BEZOUT                  77333.0
# 4  0770940D  LYCEE POLYVALENT ETIENNE BEZOUT                  77333.0
#
#   nom_de_la_commune secteur type_de_lycee  ips_voie_gt  ips_voie_pro  \
# ...
